# %% [markdown]
# ## Initialization Notebook
# This is your initialization notebook.
#
# **What's this for?**
#
# You can put custom code you want us to run every time we setup your environment in here.
#
# **Awesome! Anything I should not put in here?**
#
# Please don't install `jupyter` or `jedi` packages, they would break your Deepnote environment. Also, no need to put `!pip install`s here, we already save those automatically!
#
# **I want to learn more!**
#
# Great! Just [head over to our docs](https://deepnote.com/docs/project-initialization).

# %%
# %%bash
# # If your project has a 'requirements.txt' file, we'll install it here.
# if test -f requirements.txt
#   then
#     pip install -r ./requirements.txt
#   else echo "There's no requirements.txt, so nothing to install."
# fi
# Out:
# Collecting xmltodict==1.0.4 (from -r ./requirements.txt (line 2))
#   Downloading xmltodict-1.0.4-py3-none-any.whl.metadata (14 kB)
# Collecting pytrends==4.9.2 (from -r ./requirements.txt (line 3))
#   Downloading pytrends-4.9.2-py3-none-any.whl.metadata (13 kB)
# Collecting urllib3<2 (from -r ./requirements.txt (line 4))
#   Downloading urllib3-1.26.20-py2.py3-none-any.whl.metadata (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.1/50.1 kB 4.9 MB/s eta 0:00:00
# Collecting requests<2.31 (from -r ./requirements.txt (line 5))
#   Downloading requests-2.30.0-py3-none-any.whl.metadata (4.6 kB)
# Collecting statsmodels (from -r ./requirements.txt (line 6))
#   Downloading statsmodels-0.14.6-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl.metadata (9.5 kB)
# Collecting ipywidgets (from -r ./requirements.txt (line 7))
#   Downloading ipywidgets-8.1.8-py3-none-any.whl.metadata (2.4 kB)
# Requirement already satisfied: pandas>=0.25 in /root/venv/lib/python3.11/site-packages (from pytrends==4.9.2->-r ./requirements.txt (line 3)) (2.1.4)
# Requirement already satisfied: lxml in /root/venv/lib/python3.11/site-packages (from pytrends==4.9.2->-r ./requirements.txt (line 3)) (6.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /root/venv/lib/python3.11/site-packages (from requests<2.31->-r ./requirements.txt (line 5)) (3.4.4)
# Requirement already satisfied: idna<4,>=2.5 in /root/venv/lib/python3.11/site-packages (from requests<2.31->-r ./requirements.txt (line 5)) (3.11)
# Requirement already satisfied: certifi>=2017.4.17 in /root/venv/lib/python3.11/site-packages (from requests<2.31->-r ./requirements.txt (line 5)) (2026.1.4)
# Requirement already satisfied: numpy<3,>=1.22.3 in /root/venv/lib/python3.11/site-packages (from statsmodels->-r ./requirements.txt (line 6)) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in /root/venv/lib/python3.11/site-packages (from statsmodels->-r ./requirements.txt (line 6)) (1.11.4)
# Collecting patsy>=0.5.6 (from statsmodels->-r ./requirements.txt (line 6))
#   Downloading patsy-1.0.2-py2.py3-none-any.whl.metadata (3.6 kB)
# Requirement already satisfied: packaging>=21.3 in /root/venv/lib/python3.11/site-packages (from statsmodels->-r ./requirements.txt (line 6)) (26.0)
# Requirement already satisfied: comm>=0.1.3 in /toolkit-cache/2.3.1/python3.11/kernel-libs/lib/python3.11/site-packages (from ipywidgets->-r ./requirements.txt (line 7)) (0.2.2)
# Requirement already satisfied: ipython>=6.1.0 in /root/venv/lib/python3.11/site-packages (from ipywidgets->-r ./requirements.txt (line 7)) (9.10.0)
# Requirement already satisfied: traitlets>=4.3.1 in /root/venv/lib/python3.11/site-packages (from ipywidgets->-r ./requirements.txt (line 7)) (5.14.3)
# Collecting widgetsnbextension~=4.0.14 (from ipywidgets->-r ./requirements.txt (line 7))
#   Downloading widgetsnbextension-4.0.15-py3-none-any.whl.metadata (1.6 kB)
# Collecting jupyterlab_widgets~=3.0.15 (from ipywidgets->-r ./requirements.txt (line 7))
#   Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl.metadata (20 kB)
# Requirement already satisfied: decorator>=4.3.2 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (5.2.1)
# Requirement already satisfied: ipython-pygments-lexers>=1.0.0 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (1.1.1)
# Requirement already satisfied: jedi>=0.18.1 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (0.19.2)
# Requirement already satisfied: matplotlib-inline>=0.1.5 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (0.2.1)
# Requirement already satisfied: pexpect>4.3 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (4.9.0)
# Requirement already satisfied: prompt_toolkit<3.1.0,>=3.0.41 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (3.0.52)
# Requirement already satisfied: pygments>=2.11.0 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (2.19.2)
# Requirement already satisfied: stack_data>=0.6.0 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (0.6.3)
# Requirement already satisfied: typing_extensions>=4.6 in /root/venv/lib/python3.11/site-packages (from ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (4.15.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /root/venv/lib/python3.11/site-packages (from pandas>=0.25->pytrends==4.9.2->-r ./requirements.txt (line 3)) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /root/venv/lib/python3.11/site-packages (from pandas>=0.25->pytrends==4.9.2->-r ./requirements.txt (line 3)) (2025.2)
# Requirement already satisfied: tzdata>=2022.1 in /root/venv/lib/python3.11/site-packages (from pandas>=0.25->pytrends==4.9.2->-r ./requirements.txt (line 3)) (2025.3)
# Requirement already satisfied: parso<0.9.0,>=0.8.4 in /root/venv/lib/python3.11/site-packages (from jedi>=0.18.1->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (0.8.6)
# Requirement already satisfied: ptyprocess>=0.5 in /root/venv/lib/python3.11/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (0.7.0)
# Requirement already satisfied: wcwidth in /root/venv/lib/python3.11/site-packages (from prompt_toolkit<3.1.0,>=3.0.41->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (0.6.0)
# Requirement already satisfied: six>=1.5 in /root/venv/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=0.25->pytrends==4.9.2->-r ./requirements.txt (line 3)) (1.17.0)
# Requirement already satisfied: executing>=1.2.0 in /root/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (2.2.1)
# Requirement already satisfied: asttokens>=2.1.0 in /root/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (3.0.1)
# Requirement already satisfied: pure-eval in /root/venv/lib/python3.11/site-packages (from stack_data>=0.6.0->ipython>=6.1.0->ipywidgets->-r ./requirements.txt (line 7)) (0.2.3)
# Downloading xmltodict-1.0.4-py3-none-any.whl (13 kB)
# Downloading pytrends-4.9.2-py3-none-any.whl (15 kB)
# Downloading urllib3-1.26.20-py2.py3-none-any.whl (144 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 144.2/144.2 kB 13.8 MB/s eta 0:00:00
# Downloading requests-2.30.0-py3-none-any.whl (62 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 62.5/62.5 kB 9.4 MB/s eta 0:00:00
# Downloading statsmodels-0.14.6-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.manylinux_2_28_x86_64.whl (10.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 10.4/10.4 MB 85.7 MB/s eta 0:00:00
# Downloading ipywidgets-8.1.8-py3-none-any.whl (139 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 139.8/139.8 kB 20.5 MB/s eta 0:00:00
# Downloading jupyterlab_widgets-3.0.16-py3-none-any.whl (914 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 914.9/914.9 kB 71.0 MB/s eta 0:00:00
# Downloading patsy-1.0.2-py2.py3-none-any.whl (233 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.3/233.3 kB 34.6 MB/s eta 0:00:00
# Downloading widgetsnbextension-4.0.15-py3-none-any.whl (2.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.2/2.2 MB 74.8 MB/s eta 0:00:00
# Installing collected packages: xmltodict, widgetsnbextension, urllib3, patsy, jupyterlab_widgets, requests, statsmodels, pytrends, ipywidgets
#   Attempting uninstall: urllib3
#     Found existing installation: urllib3 2.6.3
#     Uninstalling urllib3-2.6.3:
#       Successfully uninstalled urllib3-2.6.3
#   Attempting uninstall: requests
#     Found existing installation: requests 2.32.5
#     Uninstalling requests-2.32.5:
#       Successfully uninstalled requests-2.32.5
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# snowflake-connector-python 4.3.0 requires requests<3.0.0,>=2.32.4, but you have requests 2.30.0 which is incompatible.
# trino 0.330.0 requires requests>=2.31.0, but you have requests 2.30.0 which is incompatible.
# deepnote-toolkit 2.3.1 requires cryptography<47,>=46.0.5, but you have cryptography 44.0.3 which is incompatible.
# deepnote-toolkit 2.3.1 requires idna<4,>=3.15, but you have idna 3.11 which is incompatible.
# deepnote-toolkit 2.3.1 requires pillow<13,>=12.2.0, but you have pillow 12.1.1 which is incompatible.
# deepnote-toolkit 2.3.1 requires protobuf<6,>=5.29.6, but you have protobuf 4.25.8 which is incompatible.
# deepnote-toolkit 2.3.1 requires pyjwt<3,>=2.13.0, but you have pyjwt 2.11.0 which is incompatible.
# deepnote-toolkit 2.3.1 requires pyopenssl<27,>=26.0.0, but you have pyopenssl 25.1.0 which is incompatible.
# deepnote-toolkit 2.3.1 requires requests<3,>=2.32.4, but you have requests 2.30.0 which is incompatible.
# deepnote-toolkit 2.3.1 requires urllib3<3,>=2.7.0, but you have urllib3 1.26.20 which is incompatible.
# Successfully installed ipywidgets-8.1.8 jupyterlab_widgets-3.0.16 patsy-1.0.2 pytrends-4.9.2 requests-2.30.0 statsmodels-0.14.6 urllib3-1.26.20 widgetsnbextension-4.0.15 xmltodict-1.0.4
#
# [notice] A new release of pip is available: 24.0 -> 26.1.2
# [notice] To update, run: pip install --upgrade pip
